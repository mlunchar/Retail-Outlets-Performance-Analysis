# %% [markdown]
# # Retail project decomposition

# %% [markdown]
# ## Loading the data
#
# Loading and studying briefly the data. Spotting first issues and making a list of things to check in the next step.
#
#
# ## Data Preprocessing
# *1 day*
#
# 1. <b>Changing column names.</b>
#
#
# 2. <b>Missing values.</b>
# <br>Taking a look at missing data and deciding whether it can be preprocessed at this step or after EDA.
#
#
# 3. <b>Changing data types.</b>
# <br>Reducing memory usage and taking care of dates.
#
#
# 4. <b>Duplicates.</b>
# <br>Studying in detail duplicated rows and checking the columns for duplicate values. Thinking for possible explanations. Coming to decision how to process them.
#
#
# 5. <b>Conclusion.</b>
#
#
#
# ## Exploratory Data Analysis
# *3 days*
#
# 1. <b>Missing values.</b>
# <br>Studying in detail the missing data, trying to evaluate possible reasons for it, and coming to decision how to process it if it wasn't already done in Preprocessing step.
#
#
# 2. <b>Joining both datasets together.</b>
# <br>We need to join both datasets to be able to calculate the revenue.
#
#
# 3. <b>Distributions.</b>
# <br>Studying mean values and standard deviation using `describe()` method.
#
#     * performing univariate analysis (histograms), studying outliers
#     * performing bivariate analysis (scatterplots and correlation matrix).
#
#
# 4. <b>Metrics.</b>
# <br>Per customer analysis, broken down by loyalty\non-loyalty programm. By week.
#
#     * average number of purchases per day
#     * average number of purchases per customer
#     * average revenue per purchase per customer
#     * average revenue per customer
#
#     Per shop analysis. By week.
#
#     * average number of purchases per day
#     * average number of purchases per customer
#     * average revenue per purchase per customer
#     * cumulative revenue per shop
#
#
# 5. <b>Conclusion.</b>
#
#
# ## Statistical Data Analysis
# *1 day*
#
# 1. <b>Testing hypotheses.</b>
# <br>Testing statistical hypotheses.
#
#     * The average revenue from customers with loyalty programm and without differs.
#     * The average number of purchases per customer with or without loyalty programm differs.
#
#
# 2. <b>Conclusion.</b>
#
# ## Overall Conclusion
#
# 1. <b>Conclusion.</b>
#
#
# 2. <b>Advice for business.</b>
#
# ## Building dashboard in Tableau
# *1 day*
